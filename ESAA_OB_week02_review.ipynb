# %% [markdown]
# <a href="https://colab.research.google.com/github/dcthyun0308/ESAA/blob/main/ESAA_OB_week02_review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 건설용 자갈 암석 종류 분류 AI 경진대회
#
# 1) 코드 흐름 요약
# - 데이터 전처리 및 증강 - 이미지 분류 성능을 높이기 위해 augmentation을 적용
# - 모델 구성 - timm 라이브러리를 이용해 사전학습된 모델을 불러옴.
# - 모델학습 - CrossEntropyLoss를 이용하여 다중 클래스 분류를 학습, optimizer와 learning rate scheduler를 설정하여 학습을 진행
# - 앙상블
#
# 2)
# - 새롭게 알게 된 내용 : timm 라이브러리를 활용하면 다양한 최신 CNN 및 ViT 모델을 쉽게 불러올 수 있다는 것을 알게됨, EfficientNet, RegNet, ViT 등 여러 모델을 앙상블하면 성능이 향상될 수 있다는 점을 배움
#
# - 어려운 내용 : 다양한 모델(EfficientNetV2, RegNet, TinyViT)의 구조와 차이를 이해하는 것이 어려웠음
#
# - 배울 점 : pretrained 모델을 활용하면 적은 데이터에서도 높은 성능을 얻을 수 있음
#
# - 주요 코드 3줄 이상
# import timm
# model = timm.create_model('tf_efficientnetv2_m.in21k_ft_in1k', pretrained=True, num_classes=num_classes)
#
# criterion = torch.nn.CrossEntropyLoss()
# optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
#
# outputs = model(images)
# loss = criterion(outputs, labels)
