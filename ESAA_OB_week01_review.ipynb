# %% [markdown]
# <a href="https://colab.research.google.com/github/dcthyun0308/ESAA/blob/main/ESAA_OB_week01_review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 대구 교통사고 피해 예측 AI 경진대회
#
# 1. 코드 흐름 요약
# - 파생변수 생성 : 날짜, 시간정보, 공간(위치) 정보, 도로 형태 정보, 지역별 가해운전자 & 피해운전자 평균 연령 추출, 지역별 가해운전자 & 피해운전자 평균 성별 추출, 주말 변수 추가, 외부데이터(일출일몰시각 : 해 떴는지(1) 안떴는지(0)), 지역별 위험도 변수 생성, 외부데이터 - 택시 통행량, 외부데이터 - 택시 속도
# - Age 변수 전처리
# - 외부데이터 - 전국 사고 데이터 전처리 및 이상치 제거
# - DecisionTreeRegressor 모델로 학습하고 예측
# - Optuna
# - xgb, cat, lgbm ensemble
#
#
# 2. 새롭게 알게 된 내용 / 어려운 내용 / 배울 점 등 정리 및 주요 코드 3줄 이상 작성
# - 새롭게 알게 된 내용 : 외부 데이터 활용의 중요성, 교통사고는 단순히 한 변수로 설명되는 것이 아니라 시공간적 영향을 많이 받는다는 것
# - 어려운 내용 : 교통 데이터는 단순 수치 데이터가 아니라 피처 엔지니어링 과정이 복잡했음
# - 배울 점 : 외부 데이터를 잘 활용하자
# - 주요 코드 :
# from lightgbm import LGBMRegressor
#
# model = LGBMRegressor(n_estimators=1000, learning_rate=0.05)
# model.fit(X_train, y_train)
# pred = model.predict(X_test)
